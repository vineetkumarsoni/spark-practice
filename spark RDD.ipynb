# %%
words=['this','is','the','best','mac','ever']#list of python
wordRDD=sc.parallelize(words)#change list from rdd formate
wordRDD.reduce(lambda w,v:w if len(w)<len(v) else v)#to get the shortest word
# Out:
# Out[1]: 'is'

# %%
B=sc.parallelize([1,2,3,4,5,6])
B.reduce(lambda x,y:x-y)
# Out:
# Out[2]: -19

# %%
A=sc.parallelize(range(100000000000))#want  to now how much partition it will genrate
print(A.getNumPartitions())
# Out:
# 8

# %%
sc.defaultParallelism#bydefault partition is 8
# Out:
# Out[4]: 8

# %%
rdd=sc.parallelize([1,2,3,4,5,6,7,8,9])
rdd.map(lambda x:x*100).collect()
# Out:
# Out[5]: [100, 200, 300, 400, 500, 600, 700, 800, 900]

# %%
Rdd.filter(lambda x:x%2==0).collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-1468875726619654> in <module>
# ----> 1 Rdd.filter(lambda x:x%2==0).collect()
#
# NameError: name 'Rdd' is not defined

# %%
Rdd=sc.parallelize([1,2,3,4,5,6,7,8,9])

# %%
Rdd1=Rdd.map(lambda x:x*2).collect()

# %%
rdd=sc.parallelize([1,2,3,4,5,6,7,8,9])
rdd.map(lambda x:x*100).collect()

# %%
t=["i am vineet kumar soni","whats your name"]
t_file=sc.parallelize(t)
print('map:',t_file.map(lambda line:line.split(" ")).collect())
print('flatMap:',t_file.flatMap(lambda line: line.split(" ")).collect())

# %%
rdd1=sc.parallelize([1,1,2,3])
rdd2=sc.parallelize([1,3,4,5])

# %%
rdd2=sc.parallelize(['a','b',1])
print('rdd1=',rdd1.collect())
print('rdd2=',rdd2.collect())
print('union as bags =',rdd1.union(rdd2).collect())
print('union as sets =',rdd1.union(rdd2).distinct().collect())
# Out:
# rdd1= [1, 1, 2, 3]
# rdd2= ['a', 'b', 1]
# union as bags = [1, 1, 2, 3, 'a', 'b', 1]
# union as sets = [1, 2, 3, 'b', 'a']

# %%
RDD=sc.parallelize([(1,2),(2,4),(2,6)])
print("original RDD :", RDD.collect())
print("After transformation : ",RDD.reduceByKey(lambda a,b: a+b).collect())
# Out:
# original RDD : [(1, 2), (2, 4), (2, 6)]
# After transformation :  [(1, 2), (2, 10)]

# %%
RDD=sc.parallelize([(10,2),(2,4),(7,6),(4,9),(5,0)])
print("original RDD :", RDD.collect())
print("After transformation : ",RDD.sortByKey().collect())
# Out:
# original RDD : [(10, 2), (2, 4), (7, 6), (4, 9), (5, 0)]
# After transformation :  [(2, 4), (4, 9), (5, 0), (7, 6), (10, 2)]

# %%
RDD=sc.parallelize([(10, 2), (2, 4), (7, 6), (4, 9), (5, 0)])
print("original RDD :", RDD.collect())
print("After transformation : ",RDD.mapValues(lambda a: a*a).collect())
# Out:
# original RDD : [(10, 2), (2, 4), (7, 6), (4, 9), (5, 0)]
# After transformation :  [(10, 4), (2, 16), (7, 36), (4, 81), (5, 0)]
